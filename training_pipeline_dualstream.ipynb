# %% [markdown]
# ## Setup

# %%
# sync with github so my imports are here
# !git clone https://github.com/ellylai/10707-project.git
# %cd 10707-project

# !pip install -q transformers datasets scikit-learn

import sys
sys.path.append("/content/10707-project")

# %%
# !pip install praat-parselmouth
# !pip install phonemizer
# !sudo apt-get install espeak

# %%
# imports
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm import tqdm
import numpy as np

# Adding specific directories to sys.path since they are not recognized as Python packages (missing __init__.py files).
# The parent directory '/content/10707-project' was already added in a previous cell.
import sys
if "/content/10707-project/datasets" not in sys.path:
    sys.path.append("/content/10707-project/datasets")
if "/content/10707-project/utils" not in sys.path:
    sys.path.append("/content/10707-project/utils")

from download_datasets import *
from training_utils import *
from create_dataset_splits import *
from get_waveform_dataset import *

# %% [markdown]
# # Download Data & Create Dataloaders

# %% [markdown]
# ## Data Choice 1: Unzipping XMAD Files from GDrive (Longer)
#
# 1. You must have a symlink (shortcut) from your own GDrive to the XMAD dataset, named `XMAD-dataset`.
# 2. Create a splits file that tells us which are in-domain and cross-domain splits.

# %%
import os
from google.colab import drive

# Define languages and paths
drive.mount('/content/drive')

languages = ['ar.zip', 'de.zip', 'ro.zip', 'ru.zip', 'en.zip', 'zh-cn.zip', 'es.zip']
dataset_path = '/content/drive/MyDrive/XMAD-dataset'
target_dir = '/content/xmad_local'
os.makedirs(target_dir, exist_ok=True)

# Build a single bash command string
# The '&' at the end of each unzip command sends it to the background
# 'wait' ensures the cell doesn't finish until all background tasks are done
commands = []
for lang in languages:
    zip_path = os.path.join(dataset_path, lang)
    if os.path.exists(zip_path):
        # -q for quiet (hiding the thousands of file names speeds it up)
        # -n to skip existing
        cmd = f"unzip -qn '{zip_path}' -d {target_dir} &"
        commands.append(cmd)

full_cmd = "\n".join(commands) + "\nwait\necho 'All unzipping finished!'"

# Execute everything in parallel
with open('unzip_all.sh', 'w') as f:
    f.write("#!/bin/bash\n" + full_cmd)

# !bash unzip_all.sh

# %%
# !pip install awscli
# !aws s3api get-bucket-location --bucket 10707-project
# !aws configure

# %% [markdown]
# ### Upload Files as tarball to S3 for future use

# %%
import os

# 1. Config
SOURCE_DIR = "/content/xmad_local"
TAR_NAME = "xmad_bench.tar"  # Removed .gz for 10x faster extraction later
S3_DEST = f"s3://10707-project/{TAR_NAME}"

# 2. Tune AWS CLI for a single massive stream
# !aws configure set default.s3.multipart_threshold 64MB
# !aws configure set default.s3.multipart_chunksize 64MB
# !aws configure set default.s3.max_concurrent_requests 20

# 3. Stream Tar directly to S3 (No local file created)
print(f"📦 Streaming {SOURCE_DIR} directly to {S3_DEST}...")
print("🚀 This skips local disk writes and uses your full network bandwidth.")

# -c: create, -f -: output to stdout (pipe)
# !tar -cf - -C {SOURCE_DIR} . | aws s3 cp - {S3_DEST} --expected-size 150000000000

# 4. Verification
print(f"\n✅ Upload complete. Verification:")
# !aws s3 ls {S3_DEST}

# %% [markdown]
# ## Data Choice 2: Download tarball from S3

# %%
# !pip install awscli
# !aws configure

# !mkdir -p /content/xmad_local

langs = ["de", "es", "zh-cn", "ro", "ru", "ar", "en"]

for lang in langs:
    # !aws s3 cp s3://10707-project/xmad_bench/{lang}.tar - | tar -xv -C /content/xmad_local

# %% [markdown]
# ## Create Splits File

# %%
import pandas as pd
import os
from pathlib import Path

# Root directory where your languages are unzipped
root_dir = "/content/xmad_local"
all_data = []

# Walk through all directories to find meta.csv files
for path in Path(root_dir).rglob('meta.csv'):
    # Read the individual metadata file
    df = pd.read_csv(path)

    # Identify the dataset source from the folder structure
    parent_folder = path.parent.name

    if "commonvoice" in parent_folder.lower():
        # CommonVoice contains the internal 'train' and 'test' labels
        # We use 'train' for training and 'test' as our Validation set
        df['split'] = df['split'].map({'train': 'train', 'test': 'val'})
    else:
        # AISHELL-3, M-AILABS, etc., are strictly for Cross-Domain Testing
        df['split'] = 'test'

    # Convert relative 'sample_name' paths to absolute 'file' paths for the DataLoader
    # This ensures your training_pipeline.ipynb can find the .wav files
    # The original error was 'KeyError: 'file' because the column is actually 'sample_name'
    df['file'] = df.apply(
        lambda row: os.path.join(
            path.parent,
            'fake' if row['is_fake'] == 1 else 'real',
            str(row['sample_name'])
        ),
        axis=1
    )

    # 3. Rename label for clarity in your DataLoader
    df['label'] = df['is_fake']

    all_data.append(df)

# Combine all parsed metadata into one master dataframe
if all_data:
    master_df = pd.concat(all_data, ignore_index=True)

    master_df['split'] = master_df['split'].fillna('val')

    # Split master_df into train, val, and test dataframes
    train_df = master_df[master_df['split'] == 'train'].copy()
    val_df = master_df[master_df['split'] == 'val'].copy()
    test_df = master_df[master_df['split'] == 'test'].copy()

    # Save the manifest to the path expected by your notebook
    output_path = "/content/10707-project/speechfake_splits.csv"
    master_df.to_csv(output_path, index=False)

    print(f"Successfully created: {output_path}")

    # upload to s3 bucket
    s3_dest = "s3://10707-project/xmad_bench/metadata/speechfake_splits.csv"
    # !aws s3 cp {output_path} {s3_dest}
    print(f"Successfully uploaded to S3: {s3_dest}")

    print("Split Distribution:")
    print(master_df['split'].value_counts())

    print("Unique values in the split column:")
    print(master_df['split'].unique())

    print("\nRows where split is NaN:")
    print(master_df['split'].isna().sum())
else:
    print("No meta.csv files found. Ensure the unzip process finished correctly.")

# %% [markdown]
# ### Optional Testing Cell: Truncate Splits for Testing

# %%
# ONLY RUN THIS IF YOU WANT TO TEST
import os

def clean_dataframe_by_file_existence(df_to_clean):
    """
    Removes rows from a DataFrame where the 'file' path does not exist on disk.
    """
    print(f"Cleaning dataframe: Original size = {len(df_to_clean)}")
    existing_files_mask = df_to_clean['file'].apply(lambda x: os.path.exists(x))
    cleaned_df = df_to_clean[existing_files_mask].reset_index(drop=True)
    print(f"Cleaned dataframe: New size = {len(cleaned_df)}")
    return cleaned_df

# Apply the cleaning function to your dataframes
train_df = clean_dataframe_by_file_existence(train_df)
val_df = clean_dataframe_by_file_existence(val_df)
test_df = clean_dataframe_by_file_existence(test_df)

# Truncate dataframes to specific sizes as requested
train_df = train_df.head(5000)
val_df = val_df.head(1000)
test_df = test_df.head(1000)

print(f"Final sizes: Train={len(train_df)}, Val={len(val_df)}, Test={len(test_df)}")

# %% [markdown]
# ## Dataset & Dataloader
#
# Create a class for the XMAD dataset and create dataloaders to feed into the model.

# %%
import torch
import torchaudio
import pandas as pd
from torch.utils.data import Dataset, DataLoader

# Import bio feature extractors
if "/content/10707-project/model" not in sys.path:
    sys.path.append("/content/10707-project/model")
from articulatory_features import ArticulatoryFeatureExtractor
from prosodic_features import ProsodicFeatureExtractor

class XMADDataset(Dataset):
    def __init__(self, df, target_sr=16000, max_seconds=4.0, precompute_bio=True, device='cpu',
                 precomputed_bio_seqs=None, precomputed_bio_lengths=None):
        self.df = df
        self.target_sr = target_sr
        self.max_samples = int(target_sr * max_seconds)
        self.device = device

        if precomputed_bio_seqs is not None and precomputed_bio_lengths is not None:
            self.precompute_bio = True # Ensure precompute_bio is True if precomputed features are passed
            self.bio_seqs = precomputed_bio_seqs
            self.bio_lengths = precomputed_bio_lengths
            print("Using precomputed bio features.")
        else:
            self.precompute_bio = precompute_bio # Use the provided precompute_bio flag
            if self.precompute_bio:
                print("Precomputing bio features for dataset...")
                self.art_extractor = ArticulatoryFeatureExtractor(device=self.device)
                self.pro_extractor = ProsodicFeatureExtractor()

                self.bio_seqs = []
                self.bio_lengths = []

                for idx in tqdm(range(len(self.df)), desc="Precomputing bio features"):
                    row = self.df.iloc[idx]
                    file_path = row['file']

                    # Load and process waveform
                    waveform, sr = torchaudio.load(file_path)
                    if sr != self.target_sr:
                        resampler = torchaudio.transforms.Resample(sr, self.target_sr)
                        waveform = resampler(waveform)
                    if waveform.shape[0] > 1:
                        waveform = torch.mean(waveform, dim=0, keepdim=True)
                    waveform = waveform.squeeze(0)

                    # Extract bio features
                    art_result = self.art_extractor.extract(waveform)
                    pro_result = self.pro_extractor.extract_from_segments(waveform, art_result["segments"])
                    combined_seq = self.pro_extractor.combine_with_articulatory(
                        art_result["segment_feature_sequence"],
                        pro_result["segment_feature_sequence"],
                    )
                    seq = torch.tensor(combined_seq, dtype=torch.float32)

                    if seq.shape[0] == 0:
                        art_dim = art_result["segment_feature_sequence"].shape[1]
                        pro_dim = 7  # prosodic feature dim
                        feat_dim = art_dim + pro_dim
                        seq = torch.zeros(1, feat_dim, dtype=torch.float32)

                    self.bio_seqs.append(seq)
                    self.bio_lengths.append(seq.shape[0])

                print("Bio features precomputed.")

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        file_path = row['file']
        label = row['is_fake']

        # Load audio
        waveform, sr = torchaudio.load(file_path)

        # Resample if necessary
        if sr != self.target_sr:
            resampler = torchaudio.transforms.Resample(sr, self.target_sr)
            waveform = resampler(waveform)

        # Convert to mono if stereo
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)

        # Pad or Trim to fixed length (crucial for batching)
        if waveform.shape[1] > self.max_samples:
            waveform = waveform[:, :self.max_samples]
        else:
            padding = self.max_samples - waveform.shape[1]
            waveform = torch.nn.functional.pad(waveform, (0, padding))

        if self.precompute_bio:
            return waveform.squeeze(0), self.bio_seqs[idx], self.bio_lengths[idx], torch.tensor(label)
        else:
            return waveform.squeeze(0), torch.tensor(label)

# %%
# Define collate function for batching bio features
def collate_fn(batch):
    waveforms = []
    bio_seqs = []
    bio_lengths = []
    labels = []
    for item in batch:
        waveforms.append(item[0])
        bio_seqs.append(item[1])
        bio_lengths.append(item[2])
        labels.append(item[3])
    waveforms = torch.stack(waveforms)
    max_len = max(bio_lengths) if bio_lengths else 0
    feat_dim = bio_seqs[0].shape[1] if bio_seqs else 0
    x_padded = torch.zeros(len(bio_seqs), max_len, feat_dim, dtype=torch.float32)
    for i, seq in enumerate(bio_seqs):
        x_padded[i, :seq.shape[0]] = seq
    bio_lengths = torch.tensor(bio_lengths, dtype=torch.long)
    labels = torch.stack(labels)
    return waveforms, x_padded, bio_lengths, labels

# %% [markdown]
# #### Option 1: Create Bio Features from Scratch (and save)

# %%
# Create Dataset objects
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Pass the 'device' variable to XMADDataset to utilize GPU for feature extraction

# CUT DATASET IN HALF
torch.manual_seed(707)
# 1. Generate random indices for a much smaller subset
indices = np.arange(len(train_df))
np.random.shuffle(indices)
subset_size = int(0.5 * len(train_df)) # Reduced for faster testing
train_indices = indices[:subset_size]

# 2. Create the subset
train_subset_df = train_df.iloc[train_indices].reset_index(drop=True)

train_dataset = XMADDataset(train_subset_df, device=device)
val_dataset = XMADDataset(val_df, device=device)
test_dataset = XMADDataset(test_df, device=device)

# Create DataLoaders with collate_fn
# Set num_workers to 2 or 4 to speed up loading on Colab
train_loader = DataLoader(train_dataset, batch_size=48, shuffle=True, num_workers=12, pin_memory=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=48, shuffle=False, num_workers=12, pin_memory=True, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=48, shuffle=False, num_workers=12, pin_memory=True, collate_fn=collate_fn)

print(f"Loaders created: {len(train_loader)} train batches, {len(val_loader)} val batches, {len(test_loader)} test batches.")

# %%
# Save the precomputed datasets by uploading to S3 as a tarball
import os
import torch

saved_datasets_dir = "/content/saved_xmad_datasets"
os.makedirs(saved_datasets_dir, exist_ok=True)

# Save the DataFrames locally first as they are part of the 'datasets'
train_subset_df.to_csv(os.path.join(saved_datasets_dir, "train_df.csv"), index=False)
val_df.to_csv(os.path.join(saved_datasets_dir, "val_df.csv"), index=False)
test_df.to_csv(os.path.join(saved_datasets_dir, "test_df.csv"), index=False)

# Save the precomputed bio features directly
torch.save(train_dataset.bio_seqs, os.path.join(saved_datasets_dir, "train_bio_seqs.pt"))
torch.save(train_dataset.bio_lengths, os.path.join(saved_datasets_dir, "train_bio_lengths.pt"))

torch.save(val_dataset.bio_seqs, os.path.join(saved_datasets_dir, "val_bio_seqs.pt"))
torch.save(val_dataset.bio_lengths, os.path.join(saved_datasets_dir, "val_bio_lengths.pt"))

torch.save(test_dataset.bio_seqs, os.path.join(saved_datasets_dir, "test_bio_seqs.pt"))
torch.save(test_dataset.bio_lengths, os.path.join(saved_datasets_dir, "test_bio_lengths.pt"))

print(f"Local dataset components saved to {saved_datasets_dir}/")

# --- New part: Upload to S3 as a tarball ---
S3_TARBALL_DEST = "s3://10707-project/xmad_bench/precomputed_bio_features.tar.gz"

print(f"📦 Creating tarball and streaming {saved_datasets_dir} to {S3_TARBALL_DEST}...")
# -c: create, -z: gzip, -f -: output to stdout (pipe)
# -C {saved_datasets_dir}: change directory to saved_datasets_dir before archiving
# .: archive contents of current directory (which is saved_datasets_dir)
# !tar -czf - -C {saved_datasets_dir} . | aws s3 cp - {S3_TARBALL_DEST}

print(f"✅ Successfully uploaded precomputed bio features to S3: {S3_TARBALL_DEST}")

# %% [markdown]
# #### Option 2: Load Bio Features (from pre-saved)

# %%
import os

# Define the S3 path and local destination
S3_TARBALL_DEST = "s3://10707-project/xmad_bench/precomputed_bio_features.tar.gz"
saved_datasets_dir = "/content/saved_xmad_datasets"

# Create the local directory if it doesn't exist
os.makedirs(saved_datasets_dir, exist_ok=True)

print(f"📦 Downloading and extracting precomputed bio features from {S3_TARBALL_DEST}...")

# Download the tarball from S3 and extract it directly
# -x: extract
# -v: verbose (optional, can remove for quiet)
# -z: filter through gzip
# -f -: read archive from stdin
# -C {saved_datasets_dir}: change directory to saved_datasets_dir before extracting
# !aws s3 cp {S3_TARBALL_DEST} - | tar -xzf - -C {saved_datasets_dir}

print(f"✅ Successfully downloaded and extracted precomputed bio features to {saved_datasets_dir}/")

# %%
import os
import torch
import pandas as pd
from torch.utils.data import DataLoader

# Assuming XMADDataset class is defined (from previous cells)
# and collate_fn is defined (from previous cells)

saved_datasets_dir = "/content/saved_xmad_datasets"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Reloading datasets from: {saved_datasets_dir}/")

# %%
# Load the precomputed bio features
reloaded_train_bio_seqs = torch.load(os.path.join(saved_datasets_dir, "train_bio_seqs.pt"))
reloaded_train_bio_lengths = torch.load(os.path.join(saved_datasets_dir, "train_bio_lengths.pt"))

reloaded_val_bio_seqs = torch.load(os.path.join(saved_datasets_dir, "val_bio_seqs.pt"))
reloaded_val_bio_lengths = torch.load(os.path.join(saved_datasets_dir, "val_bio_lengths.pt"))

reloaded_test_bio_seqs = torch.load(os.path.join(saved_datasets_dir, "test_bio_seqs.pt"))
reloaded_test_bio_lengths = torch.load(os.path.join(saved_datasets_dir, "test_bio_lengths.pt"))

print("Precomputed bio features loaded.")

# %%
# Reconstruct XMADDataset objects using the precomputed features
# The XMADDataset class (defined earlier) now accepts these directly.
# If we just loaded the data, and the precomputed bio sequences
reloaded_train_dataset = XMADDataset(train_df, precomputed_bio_seqs=reloaded_train_bio_seqs, precomputed_bio_lengths=reloaded_train_bio_lengths, device=device)
reloaded_val_dataset = XMADDataset(val_df, precomputed_bio_seqs=reloaded_val_bio_seqs, precomputed_bio_lengths=reloaded_val_bio_lengths, device=device)
reloaded_test_dataset = XMADDataset(test_df, precomputed_bio_seqs=reloaded_test_bio_seqs, precomputed_bio_lengths=reloaded_test_bio_lengths, device=device)

print("XMADDataset objects reconstructed.")

# %% [markdown]
# # Training

# %%
# args/configs for AcousticStream (use now for DualStream)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
lr = 0.000005 # 5e-6
epochs = 10

# %%
# wandb and huggingface setup
import wandb
from huggingface_hub import HfApi, login

# Initialize W&B
wandb.init(
    project="audio-deepfake-detection",
    name="dualstream",
    config={
        "learning_rate": lr,
        "architecture": "DualStream",
        "dataset": "XMAD-Bench",
        "epochs": epochs,
    }
)

# Login to HF (Run this once or use a token)
login()
api = HfApi()
repo_id = "Joel-10707-Project-S26/model-dualstream"

# %% [markdown]
# #### Testing before running
# 1. Test if we can write to HF
# 2. Test if we can run a training loop

# %%
import os
import huggingface_hub

# 2. Re-initialize the API object
# This forces the client to read the new environment variable
from huggingface_hub import hf_hub_download, HfApi
# api = HfApi(token=os.environ["HF_ADL_WRITE"])

# 3. Verify
try:
    user_info = api.whoami()
    print(f"Successfully switched! Logged in as: {user_info['name']}")
    print(f"Can write to Joel-10707-Project-S26: {'Yes' if any(org['name'] == 'Joel-10707-Project-S26' for org in user_info['orgs']) else 'No'}")
except Exception as e:
    print(f"Switch failed: {e}")


repo_id = "Joel-10707-Project-S26/model-dualstream"

# 1. Create a tiny test file locally
test_file = "elly_write_test.txt"
with open(test_file, "w") as f:
    f.write("Elly has write access and is ready for 10707 training!")

# 2. Attempt to upload DIRECTLY (No create_repo call)
try:
    print(f"Testing direct write access to {repo_id}...")
    api.upload_file(
        path_or_fileobj=test_file,
        path_in_repo="tests/elly_write_test.txt",
        repo_id=repo_id,
        # Since it's a private repo, specify the repo_type if needed,
        # though it defaults to model
        repo_type="model"
    )
    print("\n✅ Success! You can push to the repo.")
except Exception as e:
    print(f"\n❌ Still failing: {e}")

# %% [markdown]
# #### Optional for testing: Dummy dataset

# %%
# DUMMY DATASET
import torch
from torch.utils.data import DataLoader, TensorDataset

# --- 1. Define Dummy Dimensions ---
# Waveform length for W2V2 is typically 64,000 samples (4 seconds at 16kHz)
sample_rate = 16000
duration = 4
waveform_len = sample_rate * duration
batch_size = 2 # Small batch for testing

# --- 2. Create Synthetic Data ---
# Random noise waveforms and random binary labels (0 or 1)
dummy_waveforms = torch.randn(batch_size, waveform_len)
dummy_labels = torch.randint(0, 2, (batch_size,))

# Create a tiny dataset
dummy_dataset = TensorDataset(dummy_waveforms, dummy_labels)

# --- 3. Replace Loaders ---
# Temporarily overwrite your real loaders
test_train_loader = DataLoader(dummy_dataset, batch_size=batch_size)
test_val_loader = DataLoader(dummy_dataset, batch_size=batch_size)

print(f"✅ Created dummy loaders with shape: {dummy_waveforms.shape}")

# NOW REPLACE YOUR REAL LOADERS IN THE TRAINING LOOP WITH THESE DUMMY LOADERS TO TEST

# %% [markdown]
# #### Optional: Cut dataset in half for speed

# %%
# OPTIONAL: CUT THE TRAINING DATASET FOR SPEED
from torch.utils.data import Subset
import numpy as np

torch.manual_seed(707)

# 1. Generate random indices for a much smaller subset
indices = np.arange(len(train_dataset))
np.random.shuffle(indices)
subset_size = int(0.5 * len(train_dataset)) # Reduced for faster testing
train_indices = indices[:subset_size]

# 2. Create the subset
train_subset = Subset(train_dataset, train_indices)

# 3. Create a new loader for the loop
# Using your optimized BS=96 or 128 from earlier
train_loader_half = DataLoader(
    train_subset,
    batch_size=96,
    shuffle=True,
    num_workers=12,
    pin_memory=True,
    collate_fn=collate_fn
)

print(f"Original: {len(train_dataset)} | Sampled: {len(train_subset)}")

# %% [markdown]
# ### Model Loading

# %%
# import model and initialize optimizer
import sys
import importlib

# Ensure the model directory is in sys.path for direct module import
if "/content/10707-project/model" not in sys.path:
    sys.path.append("/content/10707-project/model")

# Force reload of dualstream and biostream to ensure latest changes are picked up
# This is crucial if the module was previously imported with an older version
if 'dualstream' in sys.modules:
    del sys.modules['dualstream']
if 'biostream' in sys.modules:
    del sys.modules['biostream']

# IMPORT THE CORRECT MODEL HERE: DUALSTREAM
from dualstream import DUALSTREAM

model = DUALSTREAM().to(device)

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=lr
)
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=0.00001, steps_per_epoch=len(train_loader), epochs=epochs
)
criterion = nn.CrossEntropyLoss()

# %%
# Resume from Checkpoint if available
repo_id = "Joel-10707-Project-S26/model-dualstream"
local_checkpoint_dir = "/content/checkpoints"

start_epoch = 0
best_val_acc = 0.0

latest_checkpoint = "None"
start_epoch = 0

try:
    print(f"Checking for existing checkpoints in {repo_id}...")
    files = api.list_repo_files(repo_id=repo_id)
    # Find all epoch checkpoints and pick the highest number
    checkpoint_files = [f for f in files if f.startswith("checkpoint-epoch-") and f.endswith(".pt")]

    if checkpoint_files:
        # Sort by epoch number to get the latest
        latest_checkpoint = sorted(checkpoint_files, key=lambda x: int(x.split('-')[-1].split('.')[0]))[-1]
        print(f"Found latest checkpoint: {latest_checkpoint}. Downloading...")

        path = hf_hub_download(repo_id=repo_id, filename=latest_checkpoint, local_dir=local_checkpoint_dir)
        checkpoint = torch.load(path, map_location=device)

        # Load states
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] # This will be the next epoch to run
        best_val_acc = checkpoint.get('val_acc', 0.0)

        print(f"✅ Successfully resumed from Epoch {start_epoch}. Best Val Acc so far: {best_val_acc:.4f}")
    else:
        print("No checkpoints found. Starting training from scratch.")
except Exception as e:
    print(f"Note: Could not resume (likely repo is empty or connection issue). Starting fresh. Error: {e}")

# %% [markdown]
# #### Sanity Checks

# %%
# SANITY CHECK 1
train_speakers = set(train_df['speaker_id'])
val_speakers = set(val_df['speaker_id'])
overlap = train_speakers.intersection(val_speakers)
print(f"Number of overlapping speakers: {len(overlap)}")

# %%
# SANITY CHECK 2
def print_layer_types(model):
    print("Layers in DUALSTREAM:")
    for name, module in model.named_modules():
        print(f"{name}: {module}")

# Example usage
print_layer_types(model)

# %%
# SANITY CHECK 3
print("Checking requires_grad status for model parameters:")
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"  {name}: {param.requires_grad}")
    else:
        print(f"  {name}: {param.requires_grad} (FROZEN)")

# %%
# SANITY CHECK 4 (Revised): Inspect Processed Biostream Data
import torch

# Load a single batch from the train loader within this cell
# This ensures the variables are defined for this cell's execution
waveforms_batch, x_padded_batch, lengths_batch, labels_batch = next(iter(train_loader))

print(f"Shape of processed biostream features (x_padded_batch): {x_padded_batch.shape}")
print(f"Data type of processed biostream features: {x_padded_batch.dtype}")
print(f"Sample of processed biostream features (first item, first 5 features of first 3 segments):\n{x_padded_batch[0, :3, :5].cpu().numpy()}")
print(f"Shape of biostream lengths (lengths_batch): {lengths_batch.shape}")
print(f"Sample of biostream lengths: {lengths_batch[:5].cpu().numpy()}")

# %% [markdown]
# ## Training Loop

# %%
def train_epoch_dualstream(model, train_loader, optimizer, scheduler, criterion, device):
    model.train()
    total_loss = 0.0
    for waveforms, x_padded, lengths, labels in tqdm(train_loader):
        waveforms, x_padded, lengths, labels = waveforms.to(device), x_padded.to(device), lengths.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(waveforms, x_padded, lengths)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()

        total_loss += loss.item()
    return total_loss / len(train_loader)

def validate_dualstream(model, val_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for waveforms, x_padded, lengths, labels in tqdm(val_loader):
            waveforms, x_padded, lengths, labels = waveforms.to(device), x_padded.to(device), lengths.to(device), labels.to(device)

            outputs = model(waveforms, x_padded, lengths)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
    acc = correct / total
    return total_loss / len(val_loader), acc

# %%
import gc
del train_df
del val_df
del test_df

del train_dataset
del val_dataset
del test_dataset

torch.cuda.empty_cache()
gc.collect()

# %%
# TRAIN
torch.cuda.empty_cache()

for epoch in range(start_epoch, epochs):
    print(f"EPOCH: {epoch+1}")
    # --- Existing Training Logic ---
    train_loss = train_epoch_dualstream(model, train_loader, optimizer, scheduler, criterion, device)
    torch.cuda.empty_cache()

    val_loss, val_acc = validate_dualstream(model, val_loader, criterion, device)

    print(f"Epoch {epoch+1}: Loss {train_loss:.4f}, Val Loss {val_loss:.4f}, Val Acc {val_acc:.4f}")

    try:
      wandb.log({
          "epoch": epoch + 1,
          "train/loss": train_loss,
          "val/loss": val_loss,
          "val/accuracy": val_acc
      })
    except Exception as e:
        print(f"Wandb Upload failed: {e}")

    # --- Checkpointing & HF Upload ---
    checkpoint_name = f"checkpoint-epoch-{epoch+1}.pt"
    checkpoint_path = os.path.join("/content/", checkpoint_name)

    # Save locally first
    torch.save({
        'epoch': epoch + 1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'val_loss': val_loss,
        'val_acc': val_acc,
    }, checkpoint_path)

    try:
        print(f"Uploading {checkpoint_name}...")
        api.upload_file(
            path_or_fileobj=checkpoint_path,
            path_in_repo=checkpoint_name,
            repo_id=repo_id,
            commit_message=f"Epoch {epoch+1} - Acc: {val_acc:.4f}"
        )
        os.remove(checkpoint_path)
    except Exception as e:
        print(f"HF Upload failed, but local checkpoint saved: {e}")

    torch.cuda.empty_cache()

# %% [markdown]
# ### Debugging after training

# %% [markdown]
# #### Debugging Step 1: Inspect Data Loader Outputs
#
# Let's pull a single batch from the training loader and inspect its shape and labels to ensure `XMADDataset` and `DataLoader` are working as expected.

# %%
import matplotlib.pyplot as plt
import torchaudio.transforms as T

# Get one batch from the (half) train loader
waveforms_batch, x_padded_batch, lengths_batch, labels_batch = next(iter(train_loader_half))

print(f"Shape of waveform batch: {waveforms_batch.shape}") # Should be (batch_size, max_samples)
print(f"Shape of bio features batch: {x_padded_batch.shape}") # Should be (batch_size, max_seq_len, feat_dim)
print(f"Bio lengths: {lengths_batch}")
print(f"Shape of labels batch: {labels_batch.shape}") # Should be (batch_size,)
print(f"Sample labels: {labels_batch[:20].tolist()}") # First 20 labels

# Visualize one waveform from the batch
# Assuming 16kHz sample rate (target_sr in XMADDataset)
sample_rate = 16000
waveform_to_plot = waveforms_batch[0].cpu().numpy()

plt.figure(figsize=(15, 4))
plt.plot(waveform_to_plot)
plt.title(f"Sample Waveform (Label: {labels_batch[0].item()})")
plt.xlabel("Sample Index")
plt.ylabel("Amplitude")
plt.grid(True)
plt.show()

# Optional: Listen to the audio (if in a Colab environment)
try:
    from IPython.display import Audio
    display(Audio(waveform_to_plot, rate=sample_rate))
except ImportError:
    print("Install `IPython.display` to listen to audio samples.")

# %% [markdown]
# #### Debugging Step 2: Check Model's Initial Output (Logits)
#
# Let's pass a sample batch through the model *before* any training updates to see what kind of output it produces. The initial logits should be somewhat random and centered around zero if the weights are initialized normally.

# %%
model.eval() # Put model in evaluation mode for this check

with torch.no_grad():
    # Use the same batch from the previous cell
    waveforms_batch_gpu = waveforms_batch.to(device)
    x_padded_batch_gpu = x_padded_batch.to(device)
    lengths_batch_gpu = lengths_batch.to(device)

    # Forward pass through the model
    # Assuming model returns (hidden_layer, logits) or just logits
    try:
        hidden_output, logits = model(waveforms_batch_gpu, x_padded_batch_gpu, lengths_batch_gpu)
    except ValueError:
        # If model only returns logits
        logits = model(waveforms_batch_gpu, x_padded_batch_gpu, lengths_batch_gpu)
        hidden_output = None

print(f"Shape of model logits: {logits.shape}") # Should be (batch_size, num_classes)
print(f"Sample logits for first item: {logits[0].cpu().numpy()}")
print(f"Sample logits for second item: {logits[1].cpu().numpy()}")

# Check initial probabilities (should be close to 0.5 for 2 classes, if untrained)
probabilities = torch.softmax(logits, dim=1)
print(f"Sample probabilities for first item: {probabilities[0].cpu().numpy()}")

# Check initial loss (should be around -log(1/num_classes) if model is untrained)
initial_loss = criterion(logits, labels_batch.to(device))
print(f"Initial loss on sample batch: {initial_loss.item():.4f}")

model.train() # Put model back in training mode

# %% [markdown]
# #### What to look for in the output of the debugging cells:
#
# *   **Waveform Shape & Labels:** Ensure `waveforms_batch.shape` is `(batch_size, 64000)` (or `max_samples`) and `labels_batch` contains `0`s and `1`s.
# *   **Sample Waveform Plot:** Does the waveform look like valid audio data? Is the label correct for what you know about the data? You might not be able to tell much from the plot, but it's a basic sanity check.
# *   **Model Logits:** For an untrained model, the logits for each class should be similar (e.g., `[0.01, -0.05]` or `[-0.1, 0.08]`) and the probabilities around 0.5. If you see very large or very small (e.g., `[100, -100]`) numbers, it might indicate bad initialization.
# *   **Initial Loss:** For a binary classification problem with `CrossEntropyLoss` and random initialization, the initial loss should be close to `log(2) \approx 0.693`. If it's vastly different (e.g., very high, or very low), something is wrong.

# %% [markdown]
# ## Test on Unseen Cross-Domain Data

# %%
# test
import torch
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.optimize import brentq
from scipy.interpolate import interp1d

def calculate_eer(y_true, y_scores):
    # y_scores should be the probability of the "Fake" class
    fpr, tpr, thresholds = roc_curve(y_true, y_scores, pos_label=1)
    fnr = 1 - tpr

    # The EER is where fpr == fnr
    eer = fpr[np.nanargmin(np.absolute((fnr - fpr)))]
    return eer

def evaluate_model(model, test_loader, device, criterion=None):
    model.eval()
    all_preds = []
    all_labels = []
    all_probs = []
    total_loss = 0.0

    print("🔍 Running Final Evaluation on Test Set...")

    with torch.no_grad():
        for waveforms, x_padded, lengths, labels in tqdm(test_loader):
            waveforms, x_padded, lengths, labels = waveforms.to(device), x_padded.to(device), lengths.to(device), labels.to(device)

            # Forward pass
            outputs = model(waveforms, x_padded, lengths)

            if criterion:
                loss = criterion(outputs, labels)
                total_loss += loss.item()

            probs = torch.softmax(outputs, dim=1)[:, 1]

            # Get predictions (assuming CrossEntropy / Multi-class)
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    # --- Metrics Calculation ---
    avg_loss = total_loss / len(test_loader) if criterion else "N/A"
    acc = accuracy_score(all_labels, all_preds)
    eer_val = calculate_eer(all_labels, all_probs)

    print("\n" + "="*30)
    print(f"TEST RESULTS")
    print(f"Average Loss: {avg_loss}")
    print(f"Accuracy:     {acc:.4f}")
    print(f"Final EER: {eer_val * 100:.2f}%")
    print("="*30)

    # Detailed Report (Precision, Recall, F1)
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    # --- Visualization: Confusion Matrix ---
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix - XMAD Test Set')
    plt.show()

    return all_labels, all_preds

# --- Execute Test ---
labels, predictions = evaluate_model(model, test_loader, device, criterion)
